# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:99% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:24pt;}
div.text_cell_render.rendered_html{font-size:20pt;}
div.text_cell_render li, div.text_cell_render p, code{font-size:22pt; line-height:30px;}
div.output {font-size:24pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:24pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:24pt;padding:5px;}
table.dataframe{font-size:24px;}
</style>
"""))
# Out:
# <style>
# div.container{width:99% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:24pt;}
# div.text_cell_render.rendered_html{font-size:20pt;}
# div.text_cell_render li, div.text_cell_render p, code{font-size:22pt; line-height:30px;}
# div.output {font-size:24pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:24pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:24pt;padding:5px;}
# table.dataframe{font-size:24px;}
# </style>

# %% [markdown]
# # 01. 빅데이터 특징과 세부내용에 대한 설명으로 알맞지 않은 것은?
# ① Veracity - 데이터의 가치를 반영한다.
#
# ② Volume - 데이터의 양이 크다.
#
# ③ Velocity - 데이터가 실시간으로 변한다.
#
# ④ Variety - 데이터가 다양하다.

# %% [markdown]
# 정답: ① Veracity - 데이터의 가치를 반영한다.
#
# 설명: ① **Veracity(정확성/신뢰성)**는 데이터의 품질, 정합성, 신뢰도를 의미합니다. '데이터의 가치를 반영한다'는 설명은 **Value(가치)**에 해당합니다.
#
# ② **Volume(규모)**은 테라바이트(TB)나 제타바이트(ZB) 등 물리적인 데이터의 거대한 양을 의미합니다.
#
# ③ **Velocity(속도)**는 데이터가 실시간으로 생성, 유통되고 이를 빠르게 분석 처리해야 하는 속도 측면을 의미합니다.
#
# ④ **Variety(다양성)**는 정형 데이터뿐만 아니라 텍스트, 영상, 음성 등 비정형 및 반정형 데이터를 포함하는 데이터 형태의 다양성을 의미합니다.

# %% [markdown]
# # 02. 데이터 수집, 전처리, 분석 작업을 모두 지원하는 것은?
# ① 데이터베이스
#
# ② 빅데이터 플랫폼
#
# ③ 데이터 시각화 툴
#
# ④ 빅데이터 가치사슬

# %% [markdown]
# 정답: ② 빅데이터 플랫폼
#
# 설명: ① 데이터베이스는 주로 데이터를 저장하고 관리하는 데 특화된 시스템입니다.
#
# ② 빅데이터 플랫폼은 데이터의 수집, 저장, 전처리, 분석, 시각화 등 데이터 생애주기 전 과정을 통합적으로 지원하는 인프라입니다.
#
# ③ 데이터 시각화 툴은 분석된 결과를 그래프나 도표로 표현하는 마지막 단계에 집중된 도구입니다.
#
# ④ 빅데이터 가치사슬은 데이터가 가치를 창출하기까지의 일련의 과정을 개념적으로 나타낸 프레임워크입니다.

# %% [markdown]
# # 03. 다음 중 개인정보에 대한 설명으로 적절하지 않은 것은?
# ① 개인정보처리자는 통계작성, 과학적 연구, 공익적 기록보존 등을 위하여 정보주체의 동의 없이 가명정보를 처리할 수 있다.
#
# ② 개인정보의 익명 처리를 위해서는 정보주체의 동의가 필요하다.
#
# ③ 개인정보의 처리와 보호에 관한 사안을 독립적으로 수행하기 위해 개인정보보호위원회를 설립했다.
#
# ④ 활용되는 정보로는 처리 수준에 따라 개인정보, 가명정보, 익명정보로 분류할 수 있다.

# %% [markdown]
# 정답: ② 개인정보의 익명 처리를 위해서는 정보주체의 동의가 필요하다.
#
# 설명: ① 가명정보는 통계 작성, 과학적 연구 등을 위해 동의 없이 처리가 가능하도록 법 개정(데이터 3법)이 이루어졌습니다.
#
# ② 익명정보는 더 이상 개인을 식별할 수 없는 정보로, 개인정보보호법의 적용 대상이 아니므로 활용 시 정보주체의 동의가 필요하지 않습니다.
#
# ③ 개인정보보호위원회는 개인정보 보호 및 처리에 관한 사항을 독립적으로 수행하기 위해 설립된 중앙행정기관입니다.
#
# ④ 데이터는 식별 가능성에 따라 개인정보, 가명정보, 익명정보로 분류됩니다.

# %% [markdown]
# # 04. 하향식 접근방법에 대한 설명 중 옳지 않은 것은?
# ① 문제 탐색 단계에서는 단순하게 나열한다.
#
# ② 문제 정의는 상위 목표를 구체화하고 하위 목표로 세분화하여 문제의 범위와 목표를 명확히 한다.
#
# ③ 해결방안 탐색은 문제에 대한 이해를 바탕으로 가능한 해결책을 찾는 과정이다.
#
# ④ 타당성 검토는 도출된 해결책이 현실적이고 실행 가능한지를 평가한다.

# %% [markdown]
# 정답: ① 문제 탐색 단계에서는 단순하게 나열한다.
#
# 설명: ① 문제 탐색(Problem Discovery) 단계에서는 단순히 문제를 나열하는 것이 아니라, 비즈니스 모델 기반의 탐색 도구나 분석 유즈케이스(Use Case)를 활용하여 체계적으로 문제를 도출해야 합니다.
#
# ② 문제 정의는 도출된 비즈니스 문제를 데이터 분석의 문제로 변환하고 구체화하는 단계입니다.
#
# ③ 해결방안 탐색은 정의된 문제를 해결하기 위해 어떤 데이터와 분석 기법이 필요한지 결정하는 과정입니다.
#
# ④ 타당성 검토는 경제적(ROI), 기술적, 데이터 타당성을 평가하여 실행 가능성을 확인합니다.

# %% [markdown]
# # 05. 빅데이터 분석 방법론의 데이터 분석 단계에서 수행하는 태스크로 옳지 않은 것은?
# ① 데이터 확인 및 추출
#
# ② 데이터 모델링
#
# ③ 모델링 적용 및 운영방안
#
# ④ 데이터 준비

# %% [markdown]
# 정답: ③ 모델링 적용 및 운영방안
#
# 설명: ① 데이터 확인 및 추출은 분석을 위해 실제 데이터를 수집하고 정제하는 단계의 태스크입니다.
#
# ② 데이터 모델링은 분석 단계의 핵심 태스크로, 기계학습 등을 이용해 모델을 구축합니다.
#
# ③ 모델링 적용 및 운영방안 수립은 분석이 완료된 후 시스템을 구현하거나 평가 및 전개 단계에서 수행되는 업무입니다.
#
# ④ 데이터 준비는 모델링을 하기 전 데이터를 변환하고 통합하는 필수적인 단계입니다.

# %% [markdown]
# # 06. 다음 중 유의미한 변수를 고르는 작업을 수행하는 단계로 알맞은 것은?
# ① 데이터 탐색
#
# ② 데이터 모델링
#
# ③ 데이터 전처리
#
# ④ 데이터 시각화

# %% [markdown]
# 정답: ② 데이터 모델링
#
# 설명: ① 데이터 탐색은 전반적인 데이터의 특성을 파악하는 단계입니다.
#
# ② 데이터 모델링 단계 내의 '변수 선택(Feature Selection)' 과정을 통해 모델 성능에 기여하는 유의미한 변수를 최종적으로 확정합니다.
#
# ③ 데이터 전처리는 결측치 처리나 이상치 제거 등 데이터의 품질을 높이는 작업입니다.
#
# ④ 데이터 시각화는 데이터를 그림으로 표현하여 통찰을 얻는 방법입니다.

# %% [markdown]
# # 07. 다음 중 분석 유형을 구분할 때 데이터 분석 방법은 충분히 이해하고 있지만 조직 내 분석 대상을 인지하지 못하는 유형은?
# ① 최적화(Optimization)
#
# ② 발견(Discovery)
#
# ③ 통찰(Insight)
#
# ④ 솔루션(Solution)

# %% [markdown]
# 정답: ③ 통찰(Insight)
#
# 설명: ① 최적화(Optimization): 분석 대상(What)도 알고 분석 방법(How)도 아는 경우입니다.
#
# ② 발견(Discovery): 분석 대상(What)도 모르고 분석 방법(How)도 모르는 경우입니다.
#
# ③ 통찰(Insight): 분석 방법(How)은 알지만 분석 대상(What)을 모를 때, 기존 데이터를 통해 새로운 인사이트를 찾는 경우입니다.
#
# ④ 솔루션(Solution): 분석 대상(What)은 알지만 분석 방법(How)을 모를 때 해결책을 찾는 경우입니다.

# %% [markdown]
# # 08. 외부 및 내부 데이터에 대한 설명으로 옳지 않은 것은?
# ① 내부 데이터는 내부 조직 간 협의에 의해 사용 가능하다.
#
# ② 내부 데이터는 조직 내부에서 생성되거나 보유하는 데이터를 의미한다.
#
# ③ 외부 데이터는 외부 출처에서 수집한 데이터를 의미하며, 보통 공개된 데이터이거나 외부 제공 업체 등을 통해 확보한다.
#
# ④ 외부 데이터는 어떤 단계에서나 사용할 수 있다.

# %% [markdown]
# 정답: ④ 외부 데이터는 어떤 단계에서나 사용할 수 있다.
#
# 설명: ① 내부 데이터는 기업이나 조직 내부 시스템(ERP, CRM 등)에서 생성되므로 협의를 통해 비교적 자유롭게 사용 가능합니다.
#
# ② 내부 데이터는 조직 내부에서 보유하고 있는 데이터가 맞습니다.
#
# ③ 외부 데이터는 공공데이터 포털, SNS, 유료 데이터 판매처 등 외부 출처에서 확보합니다.
#
# ④ 외부 데이터는 수집 시 저작권, API 호출 제한, 데이터 형식 변환 등 수집 및 정제 단계에서의 제약이 따르므로 '어떤 단계에서나 즉시' 사용 가능하다는 설명은 부적절합니다.

# %% [markdown]
# # 09. 다음 중 빅데이터 분석 절차로 알맞은 것은?
# ① 분석 기획 - 데이터 분석 - 데이터 준비 - 시스템 구현 - 평가 및 전개
#
# ② 데이터 준비 - 분석 기획 - 데이터 분석 - 평가 및 전개 - 시스템 구현
#
# ③ 분석 기획 - 데이터 준비 - 데이터 분석 - 시스템 구현 - 평가 및 전개
#
# ④ 데이터 준비 - 분석 기획 - 데이터 분석 - 평가 및 전개 - 시스템 구현

# %% [markdown]
# 정답: ③ 분석 기획 - 데이터 준비 - 데이터 분석 - 시스템 구현 - 평가 및 전개
#
# 설명: 전통적인 분석 방법론(KDD, CRISP-DM 등)은 크게 기획 → 데이터 수집/정제(준비) → 모델링(분석) → 시스템 구축 → 결과 평가 및 적용의 순서를 따릅니다. ③번이 가장 표준적인 절차입니다.

# %% [markdown]
# # 10. 다음 중 정성적 및 정량적 데이터에 대한 설명으로 옳지 않은 것은?
# ① 정성적 데이터는 질적 데이터를 표현한 것이고, 정량적 데이터는 양적 데이터를 표현한 것이다.
#
# ② 정량적 데이터는 수치적 데이터이다.
#
# ③ 정성적 데이터는 정량 데이터의 연속형으로 변환할 수 있다.
#
# ④ 정량적 데이터는 정량 데이터의 범주형으로 변환할 수 있다.

# %% [markdown]
# 정답: ③ 정성적 데이터는 정량 데이터의 연속형으로 변환할 수 있다.
#
# 설명: ① 정성(Qualitative)은 질적, 정량(Quantitative)은 양적 데이터를 의미합니다.
#
# ② 정량적 데이터는 온도, 무게, 가격 등 수치로 표현되는 데이터입니다.
#
# ③ **정성적 데이터(텍스트, 의견 등)**는 범주형으로는 변환이 쉬우나, 그 자체로 연속형 수치 데이터로 직접 변환하는 것은 원칙적으로 불가능하거나 매우 어렵습니다. (보통 인코딩을 통해 숫자로 바꾸지만 이는 '연속성'과는 차이가 있습니다.)
#
# ④ 정량적 데이터(나이 등)는 10대, 20대와 같은 범주형(정성적 성격)으로 변환이 가능합니다.

# %% [markdown]
# # 11. 비정형 데이터로 옳지 않은 것은?
# ① 거래 내역(Transaction) 데이터
#
# ② 음성 데이터
#
# ③ 이미지 데이터
#
# ④ 영상 데이터

# %% [markdown]
# 정답: ① 거래 내역(Transaction) 데이터
#
# 설명: ① 거래 내역은 데이터베이스의 테이블 형태로 저장되는 전형적인 정형 데이터입니다.
#
# ②, ③, ④ 음성, 이미지, 영상은 형태가 정해져 있지 않은 대표적인 비정형 데이터입니다.

# %% [markdown]
# # 12. 데이터와 변수에 대한 관계로 잘못 짝지어진 것은?
# ① 연령 - 비율변수
#
# ② 성별 - 명목변수
#
# ③ 매출액 - 서열변수
#
# ④ 온도 - 등간변수

# %% [markdown]
# 정답: ③ 매출액 - 서열변수
#
# 설명: ① 연령은 0세라는 절대 영점이 존재하므로 비율변수입니다.
#
# ② 성별은 단순한 분류이므로 명목변수입니다.
#
# ③ 매출액은 0원이 절대 영점이며 수치 간 비율 계산이 가능하므로 비율변수입니다. 서열변수는 순위(1등, 2등)를 나타내는 변수입니다.
#
# ④ 온도는 0도가 '없음'을 의미하지 않는 상대적 수치이므로 등간변수입니다.

# %% [markdown]
# # 13. 데이터 변환에 대한 설명으로 가장 옳은 것은?
# ① 금융 데이터에서 이상거래를 감지해 데이터 분포를 매끄럽게 만듦 - 정규화
#
# ② 연령을 기준으로 10~30은 청년, 40~60은 중년으로 나눔 - 범주화
#
# ③ 데이터가 가지고 있는 특성의 개수를 줄임 - 표준화
#
# ④ 딥러닝 모델에서 이미지를 학습할 때, 이미지 데이터를 [0, 1] 범위 변환 - 일반화

# %% [markdown]
# 정답: ② 연령을 기준으로 10~30은 청년, 40~60은 중년으로 나눔 - 범주화
#
# 설명: ① 이상거래 감지를 위해 분포를 조절하는 것은 평활화(Smoothing)나 이상치 처리에 가깝습니다.
#
# ② 수치형 데이터를 특정 구간으로 묶어 집단화하는 것을 **범주화(Categorization/Binning)**라고 합니다.
#
# ③ 특성의 개수를 줄이는 것은 '차원 축소'입니다. 표준화는 단위(Scale)를 맞추는 작업입니다.
#
# ④ 데이터를 [0, 1] 범위로 바꾸는 것은 정규화(Normalization) 또는 Min-Max Scaling입니다. 일반화는 모델이 새로운 데이터에 잘 적응하는 성질을 뜻합니다.

# %% [markdown]
# # 14. 가명처리 기법에서 순서를 섞어 개인정보를 알아볼 수 없게 하는 것은?
# ① 가명처리 - 휴리스틱 익명화
#
# ② 총계처리 - 재배열
#
# ③ 일반화 - 마스킹
#
# ④ 최소화 - 잡음(Noise) 추가

# %% [markdown]
# 정답: ② 총계처리 - 재배열
#
# 설명: 가명처리 기법 중 데이터의 레코드 순서를 무작위로 섞어서 특정 개인과 항목의 연결성을 끊는 기법을 재배열(Shuffling) 또는 순열이라고 합니다.
#
# 15. 데이터 마스킹(Data Masking)에 대한 설명으로 가장 옳지 않은 것은?
# 정답: ② 데이터 마스킹 수준이 높으면 데이터를 식별, 예측하기 쉬워진다.
#
# 설명: ① 마스킹(예: 홍*동)을 과도하게 하면 정보가 소실되거나 삭제된 것과 다름없게 됩니다.
#
# ② 마스킹 수준이 높을수록(정보를 많이 가릴수록) 개인을 식별하거나 원래 데이터를 예측하기는 더 어려워집니다.
#
# ③ 마스킹은 이름, 주민번호 등 식별 요소를 가리면서도 전체 데이터의 틀은 유지하는 장점이 있습니다.
#
# ④ 마스킹을 너무 적게 하면 다른 데이터와 결합하여 추론이 가능해질 위험이 있습니다.

# %% [markdown]
# # 15. 데이터 마스킹(Data Masking)에 대한 설명으로 가장 옳지 않은 것은?
# ① 데이터 마스킹을 철저히 하면 데이터가 삭제될 수 있다.
#
# ② 데이터 마스킹 수준이 높으면 데이터를 식별, 예측하기 쉬워진다.
#
# ③ 데이터 마스킹은 개인 식별 요소를 제거하는 것이 가능하며, 원 데이터 구조에 대한 변형이 적다는 장점이 있다.
#
# ④ 데이터 마스킹을 과도하게 적용할 경우 데이터 필요 목적에 활용하기 어려우며, 수준이 낮을 경우 특정한 값에 대한 추론이 가능하다는 단점이 있다.

# %% [markdown]
# 정답: ② 데이터 마스킹 수준이 높으면 데이터를 식별, 예측하기 쉬워진다.
#
# 설명: ① 마스킹(예: 홍*동)을 과도하게 하면 정보가 소실되거나 삭제된 것과 다름없게 됩니다.
#
# ② 마스킹 수준이 높을수록(정보를 많이 가릴수록) 개인을 식별하거나 원래 데이터를 예측하기는 더 어려워집니다.
#
# ③ 마스킹은 이름, 주민번호 등 식별 요소를 가리면서도 전체 데이터의 틀은 유지하는 장점이 있습니다.
#
# ④ 마스킹을 너무 적게 하면 다른 데이터와 결합하여 추론이 가능해질 위험이 있습니다.

# %% [markdown]
# # 16. 데이터 웨어하우스(Data Warehouse)에 대한 특징으로 옳지 않은 것은?
# ① 휘발성(Volatile)
#
# ② 주제 지향적(Subject-oriented)
#
# ③ 통합적(Integrated)
#
# ④ 시계열적(Time-series)

# %% [markdown]
# 정답: ① 휘발성(Volatile)
#
# 설명: 데이터 웨어하우스의 4대 특징은 다음과 같습니다.
#
# 주제 지향적: 특정 업무가 아닌 주제별로 구성.
#
# 통합적: 여러 소스의 데이터를 일관된 형식으로 통합.
#
# 시계열적: 과거부터 현재까지의 데이터를 시간에 따라 저장.
#
# 비휘발성(Non-volatile): 한 번 저장된 데이터는 삭제나 수정이 거의 발생하지 않고 조회만 수행됨. 따라서 ①번 휘발성이 틀린 설명입니다.

# %% [markdown]
# # 17. 다음 중 분산파일시스템으로 옳지 않은 것은?
# ① Hbase
#
# ② Ceph
#
# ③ HDFS
#
# ④ GFS

# %% [markdown]
# 정답: ① Hbase
#
# 설명: ① Hbase는 HDFS 위에서 동작하는 **분산 데이터베이스(NoSQL)**입니다. 파일시스템 자체가 아닙니다.
#
# ② Ceph, ③ HDFS(Hadoop Distributed File System), ④ GFS(Google File System)는 모두 데이터를 여러 서버에 나누어 저장하는 분산파일시스템입니다.

# %% [markdown]
# # 18. Key-value 데이터 베이스에 대한 설명으로 가장 옳지 않은 것은?
# ① 키와 값으로 이루어짐
#
# ② 값은 모든 유형의 데이터로 저장이 가능
#
# ③ 관계나 복잡한 쿼리 처리 유용
#
# ④ 주로 빠른 읽기 및 쓰기 작업에 최적화

# %% [markdown]
# 정답: ③ 관계나 복잡한 쿼리 처리 유용
#
# 설명: ① Key-Value DB는 고유한 키와 그에 대응하는 값을 저장하는 구조입니다.
#
# ② 값(Value)은 문자열, 객체 등 다양한 형태로 저장이 가능합니다.
#
# ③ 복잡한 조인(Join)이나 관계 연산은 RDBMS의 특징이며, Key-Value DB는 단순 구조이므로 복잡한 쿼리 처리에는 적합하지 않습니다.
#
# ④ 구조가 단순한 만큼 읽고 쓰는 속도가 매우 빠릅니다.

# %% [markdown]
# # 19. 다음 중 MongoDB, Cassandra DB와 같이 반정형, 비정형 데이터를 처리하기에 적합한 데이터베이스는?
# ① In-memory DB
#
# ② DFS
#
# ③ NoSQL
#
# ④ RDBMS

# %% [markdown]
# 정답: ③ NoSQL
#
# 설명: 전통적인 RDBMS(관계형 DB)의 한계를 극복하고 유연한 데이터 모델을 사용하는 데이터베이스를 NoSQL(Not Only SQL)이라고 하며, 몽고디비나 카산드라가 대표적입니다.

# %% [markdown]
# # 20. 다음 중 결측값 대체에 대한 설명으로 가장 옳지 않은 설명은?
# ① 결측값을 분산/평균 등으로 대체하면 분산이 감소한다.
#
# ② 연속형 변수의 결측값을 대체할 때는 평균 또는 중앙값을 활용할 수 있다.
#
# ③ 범주형 변수의 결측값을 대체할 때는 최빈값을 사용할 수 있다.
#
# ④ 자가회귀로 결측값을 대체하면 상관성이 낮아지고 분산이 커진다.

# %% [markdown]
# 정답: ④ 자가회귀로 결측값을 대체하면 상관성이 낮아지고 분산이 커진다.
#
# 설명: ① 평균이나 중앙값으로 대체하면 데이터가 중앙으로 몰리게 되어 전체적인 분산이 감소합니다.
#
# ②, ③ 연속형은 평균/중앙값, 범주형은 최빈값으로 대체하는 것이 일반적입니다.
#
# ④ 자가회귀(Imputation using Regression) 등 모델 기반 대체법은 변수 간의 관계를 유지하려 노력하므로, 단순 대체법보다 상관성을 잘 유지하며 분산 왜곡을 줄이는 장점이 있습니다. '상관성이 낮아진다'는 설명은 틀렸습니다.

# %% [markdown]
# # 21. 다음 박스플롯(상자그림)에 대한 설명으로 옳은 것은?
# (이미지 내 박스플롯 수치 참조: 1반 중위수 74, 2반 중위수 88 등)
#
# ① 1반의 중위수가 2반의 중위수보다 높다.
#
# ② 1반의 최대값과 최소값의 차이가 2반보다 크다.
#
# ③ 2반의 최대값이 1반의 최대값보다 높다.
#
# ④ 95%의 신뢰도로 1반의 평균 점수가 높다.

# %% [markdown]
# 정답: ③ 2반의 최대값이 1반의 최대값보다 높다.
#
# 설명: 박스플롯의 구성 요소를 보면 다음과 같습니다.
#
# 가운데 선: 중위수(Median)
#
# 박스 상단: 3사분위수(Q3)
#
# 위쪽 수염 끝: 최대값(이상치 제외 시) 문항 내용상 2반의 중위수(88)가 1반(74)보다 높으며, 시각적으로도 2반의 상단 수염 위치(최대값)가 1반보다 높게 위치합니다.

# %% [markdown]
# # 22. 파생변수에 대한 설명으로 가장 옳지 않은 것은?
# ① 시점에 따라 파생변수를 생성할 수 있다.
#
# ② 상관 정도에 따라 파생변수를 고려한다.
#
# ③ 설명변수, 독립변수의 교호작용에 의해서 생성할 수 있다.
#
# ④ 특정 조건의 파생변수를 만들 수 있다.

# %% [markdown]
# 정답: ② 상관 정도에 따라 파생변수를 고려한다.
#
# 설명: ① 시간, 요일 등 시점 기반 파생변수 생성은 매우 흔합니다.
#
# ② 상관관계가 너무 높은 변수들은 다중공선성 문제를 일으키므로, 오히려 변수를 제거하거나 통합해야 합니다. 단순히 '상관 정도에 따라 파생변수를 만든다'는 논리는 분석 모델의 안정성을 해칠 수 있습니다.
#
# ③ 두 변수의 곱(교호작용) 등을 통해 새로운 파생변수를 만들 수 있습니다.
#
# ④ 특정 조건(예: 구매 금액 100만 원 이상 여부)을 만족하는 변수를 생성할 수 있습니다.

# %% [markdown]
# # 23. 다음 중 음수 데이터는 불가능하며, 양수 데이터로 정규분포에 근사하게 변환하는 방법은?
# ① Min-Max 정규화
#
# ② Z-score 표준화
#
# ③ 구간화(Binning)
#
# ④ Box-Cox 변환

# %% [markdown]
# 정답: ④ Box-Cox 변환
#
# 설명:Box-Cox 변환은 정규성을 따르지 않는 데이터를 정규분포에 가깝게 만들기 위해 사용하는 파라미터 기반 변환 기법으로, 데이터가
# **반드시 양수($y > 0$)**여야 한다는 제약이 있습니다.

# %% [markdown]
# # 24. 표준화에 대한 설명으로 알맞은 것은?
# ① 두 개 이상의 데이터를 합쳐서 하나의 데이터로 표현하는 것이다.
#
# ② 노이즈를 제거해서 매끄럽게 한다.
#
# ③ 데이터를 특정 범위로 변환하여 데이터 간의 크기 차이를 줄이는 것이다.
#
# ④ 표준화한 값에는 단위가 없다.

# %% [markdown]
# 정답: ③ 데이터를 특정 범위로 변환하여 데이터 간의 크기 차이를 줄이는 것이다.
#
# 설명: ① 데이터를 합치는 것은 통합(Integration)입니다.
#
# ② 노이즈 제거는 평활화(Smoothing)입니다.
#
# ③ 표준화(Standardization)는 평균을 0, 표준편차를 1로 변환하여 서로 다른 변수들 간의 척도(Scale)를 맞추는 과정입니다.
#
# ④ 표준화된 값(Z-score)은 원래의 단위를 상쇄시킨 무차원 수치이므로 '단위가 없다'는 표현도 이론적으로는 맞지만, 표준화의 가장 본질적인 목적은 ③번입니다.

# %% [markdown]
# # 25. 다음 중 데이터 정제 과정 중 변환에 대한 사례로 가장 옳지 않은 것은?
# ① 날짜 데이터(2022년 1월 3일) – YYYY/MM/DD
#
# ② 연령 데이터(11, 24, 33, 38) – 10대, 20대, 30대로 범주화
#
# ③ 키 데이터(170, 165, 153, 152) – 평균 키를 0으로, 표준편차를 1로 표준화
#
# ④ 대량의 이메일 목록 – 작은 그룹으로 배치

# %% [markdown]
# 정답: ④ 대량의 이메일 목록 – 작은 그룹으로 배치
#
# 설명: ①, ②, ③ 날짜 형식 변경, 범주화(Binning), 표준화는 모두 데이터 변환(Transformation)의 전형적인 사례입니다.
#
# ④ 이메일 목록을 작은 그룹으로 나누는 것은 단순한 데이터 분할(Partitioning) 또는 샘플링 작업이지, 데이터의 속성 자체를 바꾸는 '변환'으로 보기 어렵습니다.

# %% [markdown]
# # 26. 불균형 데이터에 대한 설명으로 옳지 않은 것은?
# ① 불균형 데이터에서는 주로 소수 클래스의 샘플 수가 매우 적다.
#
# ② 시각화하여 산포도를 그려볼 수 있다.
#
# ③ 상자그림을 통해 데이터의 분포와 이상값을 확인할 수 있다.
#
# ④ 소수 클래스를 언더 샘플링하여 해결한다.

# %% [markdown]
# 정답: ④ 소수 클래스를 언더 샘플링하여 해결한다.
#
# 설명: 불균형 데이터를 해결하기 위해 샘플 수가 적은 쪽을 늘리는 **오버 샘플링(Oversampling)**이나, 많은 쪽을 줄이는 **언더 샘플링(Undersampling)**을 모두 사용할 수 있습니다. ④번 문항은 소수 클래스(이미 적은 쪽)를 언더 샘플링(더 줄임)한다고 설명했으므로 틀린 방법입니다.

# %% [markdown]
# 27. 다음 중 서열척도 변수들 간의 상관관계를 측정할 때 사용하는 값은?
# ① 피어슨 상관계수(Pearson) ② 점 양분 상관계수(Point-biserial) ③ 스피어만 상관계수(Spearman) ④ 파이계수(Phi)

# %% [markdown]
# 정답: ③ 스피어만 상관계수(Spearman)
#
# 설명: ① 피어슨: 연속형 변수 간의 선형 관계.
#
# ③ 스피어만: 데이터의 **순위(Rank)**를 기반으로 하는 상관계수로, 서열척도나 비선형 관계 분석에 사용됩니다.

# %% [markdown]
# 28. 암 발생률과 재산의 상관관계를 다른 변수들을 제외하고 분석하고 싶을 때 사용하는 기법은?
# ① 군집분석 ② 편상관분석 ③ F분포 ④ 카이제곱

# %% [markdown]
# 정답: ② 편상관분석
#
# 설명: 두 변수 사이의 순수한 상관관계를 파악하기 위해, 관계에 영향을 줄 수 있는 제3의 변수(통제 변수)의 영향을 제거하고 분석하는 기법을 **편상관분석(Partial Correlation Analysis)**이라고 합니다.

# %% [markdown]
# # 29. 단일봉이면서 우측으로 꼬리가 긴 분포의 대표값에 대한 설명으로 옳은 것은?
# ① 평균 < 최빈값 < 중앙값
#
# ② 최빈값 < 중앙값 < 평균
#
# ③ 중앙값 < 최빈값 < 평균
#
# ④ 최빈값 < 평균 < 중앙값

# %% [markdown]
# 정답: ② 최빈값 < 중앙값 < 평균
#
# 설명: 오른쪽으로 꼬리가 길게 늘어진 분포(Positive Skewness)는 극단적으로 큰 값들이 존재하기 때문에 값이 큰 쪽으로 당겨지는 정도가 평균 > 중앙값 > 최빈값 순서가 됩니다.

# %% [markdown]
# # 30. 데이터의 쏠림 현상이나 분포 비대칭성을 확인할 수 있는 가장 알맞은 기법은?
# ① 분산(Variance) 분석
#
# ② 왜도(Skewness)
#
# ③ 첨도(Kurtosis)
#
# ④ 히스토그램(Histogram) 분석

# %% [markdown]
# 정답: ② 왜도(Skewness)
#
# 설명:
#
# 왜도(Skewness): 분포의 비대칭 정도(왼쪽/오른쪽 쏠림)를 나타냅니다.
#
# 첨도(Kurtosis): 분포의 뾰족한 정도를 나타냅니다.

# %% [markdown]
# # 31. 다음 중 점수가 각각 60, 70, 80일 때 표본분산으로 옳은 것은?
# ① 10
#
# ② 20
#
# ③ 100
#
# ④ 200

# %% [markdown]
# 정답: ③ 100
#
# 설명:
#
# 평균: $(60+70+80) / 3 = 70
#
# $편차 제곱합: $(60-70)^2 + (70-70)^2 + (80-70)^2 = 100 + 0 + 100 = 200
#
# $표본분산: 편차 제곱합을 $(n-1)$로 나눕니다.
#
# $200 / (3-1) = 100$

# %% [markdown]
# # 32. A그룹은 100명 중 71명 투표, B그룹은 200명 중 134명 투표했을 때, 모평균 pA와 pB에 대해 pA - pB값의 추정치로 옳은 것은?
# ① 0.04
#
# ② 1.38
#
# ③ 0.67
#
# ④ 0

# %% [markdown]
# 정답: ① 0.04
#
# 설명:
#
# $pA$의 추정치(표본비율): $71 / 100 = 0.71
#
# $$pB$의 추정치(표본비율): $134 / 200 = 0.67
#
# $$pA - pB = 0.71 - 0.67 = 0.04$

# %% [markdown]
# # 33. 다음 중 기초 통계량과 그래프로 확인할 수 없는 것은?
# ① 통계적 유의성
#
# ② 결측값
#
# ③ 이상값
#
# ④ 데이터 분포

# %% [markdown]
# 정답: ① 통계적 유의성
#
# 설명:
#
# 기초 통계(평균, 분산 등)와 그래프(히스토그램, 박스플롯)로는 결측값, 이상값, 데이터의 분포 등을 눈으로 확인할 수 있지만, 가설이 맞는지 틀린지를 결정하는 **통계적 유의성(P-value 등)**은 가설 검정 절차를 거쳐야만 알 수 있습니다.

# %% [markdown]
# # 34. 모자이크 플롯(그림)에 대한 설명으로 적절하지 않은 것은?
# ① 히스토그램 안에 히스토그램을 겹쳐 그린 것이다.
#
# ② 상대적인 빈도 차이나 구조를 시각적으로 파악한다.
#
# ③ 범주형 변수 간의 관계를 시각화한다.
#
# ④ 직사각형 면적 하나가 빈도를 나타낸다.

# %% [markdown]
# 정답: ① 히스토그램 안에 히스토그램을 겹쳐 그린 것이다.
#
# 설명:
#
# 모자이크 플롯은 두 개 이상의 범주형 변수 간의 관계를 사각형의 면적으로 나타내는 그래프입니다.
#
# 히스토그램(연속형 변수용)을 겹쳐 그린 것이 아닙니다.

# %% [markdown]
# # 35. 기술 통계량으로 옳지 않은 것은?
# ① 최대값
#
# ② 중앙값
#
# ③ 이상값
#
# ④ 분산

# %% [markdown]
# 정답: ③ 이상값
#
# 설명:
#
# 기술 통계량은 데이터의 특성을 요약하는 수치(최대값, 중앙값, 분산, 평균 등)를 의미합니다.
#
# '이상값'은 통계량이 아니라 데이터의 특정 상태를 나타내는 개별 데이터를 의미하므로 기술 통계량 범주에 직접 포함되지 않습니다. (다만 이상치를 찾기 위해 기술 통계량을 사용합니다.)

# %% [markdown]
# # 36. 다음 중 샘플링 기법이 아닌 것은?
# ① Metropolis-Hastings Algorithm
#
# ② Perfect Sampling
#
# ③ EM Algorithm
#
# ④ Rejection Sampling

# %% [markdown]
# 정답: ③ EM Algorithm
#
# 설명:
#
# ①, ②, ④는 확률분포에서 표본을 추출하는 샘플링 알고리즘입니다.
#
# ③ EM 알고리즘은 잠재 변수가 있는 모델의 최대우도(Maximum Likelihood)를 찾기 위한 최적화 알고리즘이지 샘플링 기법이 아닙니다.

# %% [markdown]
# # 37. 10번 중 7번 이상 성공할 확률에 대해 다음과 같을 때, 제2종 오류를 범할 확률은?
# 귀무가설($H_0$) = $\frac{1}{2}$, 대립가설($H_1$) = $\frac{2}{3}$
#
# ① $\sum_{i=7}^{10} \binom{10}{i} (\frac{2}{3})^i \times (\frac{1}{3})^{10-i}$
#
# ② $\sum_{i=0}^{6} \binom{10}{i} (\frac{2}{3})^i \times (\frac{1}{3})^{10-i}$
#
# ③ $\sum_{i=7}^{10} (\frac{1}{2})^i$
#
# ④ $\sum_{i=0}^{6} (\frac{1}{2})^i$

# %% [markdown]
# 정답: ② $\sum_{i=0}^{6} \binom{10}{i} (\frac{2}{3})^i \times (\frac{1}{3})^{10-i}$
#
# 설명:
#
# 제2종 오류($\beta$): 대립가설이 참인데 귀무가설을 채택하는 경우입니다.기각역이 '7번 이상'이므로, 채택역은 '6번 이하'입니다.
#
# 따라서 대립가설의 확률(2/3)을 기준으로 0번부터 6번까지 성공할 확률을 모두 더한 것이 제2종 오류가 됩니다.

# %% [markdown]
# # 38. 모집단에서 표본 N을 추출하여 표본평균의 분포를 구할 때 옳지 않은 것은?
# ① N 갯수(표본크기)와 상관없이 표본평균은 모집단의 평균에 수렴한다.
#
# ② 표본평균은 모집단의 기대값을 의미한다.
#
# ③ N 크기가 커지면 표본평균의 분산은 커지고, 표준편차는 작아진다.

# %% [markdown]
# 정답: ③ N 크기가 커지면 표본평균의 분산은 커지고, 표준편차는 작아진다.
#
# 설명:
#
# 표본의 크기($N$)가 커질수록 표본평균의 분산은 $ \frac{\sigma^2}{N} $이 되므로, 분산은 작아지고 분포는 모평균 주위에 더 조밀하게 모이게 됩니다.

# %% [markdown]
# # 39. 다음 보기의 설명으로 옳은 것은?
# 동일한 확률분포를 가진 독립확률변수 n개의 평균의 분포는 n이 적당히 크다면 정규분포에 가까워진다는 이론
#
# ① 중심극한정리
#
# ② 대수의 법칙
#
# ③ 카이제곱검정
#
# ④ t-분포

# %% [markdown]
# "동일한 확률분포를 가진 독립확률변수 n개의 평균의 분포는 n이 적당히 크다면 정규분포에 가까워진다는 이론"
#
# 정답: ① 중심극한정리
#
# 설명: 모집단의 분포와 상관없이 표본의 크기가 커지면 표본평균들의 분포가 정규분포를 따른다는 통계학의 핵심 정리는 **중심극한정리(Central Limit Theorem)**입니다.

# %% [markdown]
# # 40. 아래 수식을 보고 불편추정량과 일치추정량에 대한 설명으로 옳은 것은?
# $$S^1 = \frac{1}{n} \sum_{i=1}^{n} (X_i - \bar{X})^2$$$$S^2 = \frac{1}{n-1} \sum_{i=1}^{n} (X_i - \bar{X})^2$$
#
# ① $S^1$은 불편추정량이다.
#
# ② $S^2$는 일치추정량이 아니다.
#
# ③ $S^2$의 bias는 0이다.
#
# ④ $S^1$과 $S^2$ 모두 가설검정에서 사용한다.

# %% [markdown]
# 정답: ③ $S^2$의 bias는 0이다.
#
# 설명:
#
# $S^2$는 분모를 $(n-1)$로 나눈 불편분산입니다. 불편(Unbiased) 추정량이라는 말 자체가 편향(Bias)이 0이라는 뜻입니다.
#
# 참고로 $S^1$은 $n$으로 나누었으므로 표본이 작을 때 편향이 발생합니다.

# %% [markdown]
# # 41. 모델의 배치에 관한 설명으로 옳지 않은 것은?
# ① 배치의 크기가 커지면 학습시간은 줄어들지만, 정확성에는 영향을 끼치지 않는다.
#
# ② 배치크기는 학습속도에 영향을 주지만, 학습성능에는 영향을 끼치지 않는다.
#
# ③ 배치크기가 너무 크면 메모리 문제가 발생한다.
#
# ④ 배치크기가 작으면 노이즈를 반영하여, 모델의 학습에 악영향을 줄 수 있다.

# %% [markdown]
# 정답: ② 배치크기는 학습속도에 영향을 주지만, 학습성능에는 영향을 끼치지 않는다.
#
# 설명: 배치 크기는 메모리 사용량뿐만 아니라 모델의 일반화 성능(학습 성능)에도 큰 영향을 미칩니다. 너무 큰 배치는 지역 최솟값(Local Minima)에 빠지기 쉽게 만들고, 너무 작은 배치는 학습이 불안정해질 수 있습니다.

# %% [markdown]
# # 42. 모델의 편향과 분산 관계에 대한 설명으로 적절한 것은?
# ① 좋은 모델은 편향이 작고 분산도 작다.
#
# ② 좋은 모델은 편향이 크고 분산도 작다.
#
# ③ 좋은 모델은 편향이 작고 분산도 크다.
#
# ④ 모델의 편향과 분산은 서로 독립적이다.

# %% [markdown]
# 정답: ① 좋은 모델은 편향이 작고 분산도 작다.
#
# 설명: 모델의 이상적인 목표는 과소적합되지 않도록 편향을 줄이고, 과적합되지 않도록 분산을 줄여 둘 다 낮은 상태를 유지하는 것입니다. (다만 실제로는 트레이드오프 관계가 존재합니다.)

# %% [markdown]
# # 43. 다음 중 가중치 제곱합을 최소화하는 제약을 주는 기법으로 옳은 것은?
# ① 라쏘회귀
#
# ② 릿지회귀
#
# ③ 엘라스틱넷
#
# ④ 로지스틱회귀

# %% [markdown]
# 정답: ② 릿지회귀(Ridge)
#
# 설명:
#
# 라쏘(Lasso): 가중치 절대값의 합(L1 규제)을 최소화.
#
# 릿지(Ridge): 가중치 제곱합(L2 규제)을 최소화.

# %% [markdown]
# # 44. 다중공선성의 설명으로 옳은 것은?
# ① 독립변수들 간의 상관성을 나타내는 값으로, 분산관계율을 나타낸다.
#
# ② 독립변수들 간의 상관성을 나타내는 값으로, 클수록 모델에 악영향을 미친다.
#
# ③ 종속변수들 간의 분산크기에 대한 성질이다.
#
# ④ 종속변수들 간의 상관성을 나타내는 값으로, 작을수록 모델에 악영향을 미친다.

# %% [markdown]
# 정답: ② 독립변수들 간의 상관성을 나타내는 값으로, 클수록 모델에 악영향을 미친다.
#
# 설명: 다중공선성은 독립변수들끼리 서로 강한 상관관계를 가질 때 발생하며, 이는 회귀 계수 추정을 불안정하게 만들어 모델의 예측력과 해석력을 떨어뜨리는 악영향을 줍니다.

# %% [markdown]
# # 45. 다음 중 결정계수($R^2$)에 대한 설명으로 옳은 것은?
# ① 독립변수가 종속변수에 의해 설명되는 오차의 비율을 나타낸다.
#
# ② 범위는 보통 0과 1 사이에 있으며, 모델이 데이터를 얼마나 잘 설명하는지의 정도를 나타낸다.
#
# ③ 독립 변수끼리의 관계를 나타낸 것이다.
#
# ④ 다중선형회귀 모델에서는 1개만 존재한다.

# %% [markdown]
# 정답: ② 범위는 보통 0과 1 사이에 있으며, 모델이 데이터를 얼마나 잘 설명하는지의 정도를 나타낸다.
#
# 설명: 결정계수는 전체 변동 중 모델에 의해 설명되는 변동의 비율입니다. 1에 가까울수록 모델의 설명력이 높음을 의미합니다.

# %% [markdown]
# # 46. 선형 회귀분석과 로지스틱 회귀분석에 대해 설명으로 옳지 않은 것은?
# ① 모두 오차항의 가정이 필요하다.
#
# ② 선형 회귀분석에서의 정규성 가정은 잔차가 정규분포를 따른다는 것을 의미한다.
#
# ③ 로지스틱 회귀분석은 종속 변수가 범주형인 경우에 사용한다.
#
# ④ 모두 최대우도법으로 회귀계수를 추정한다.

# %% [markdown]
# 정답: ④ 모두 최대우도법으로 회귀계수를 추정한다.
#
# 설명:
#
# 선형 회귀: 주로 **최소제곱법(Least Squares Method)**을 사용하여 계수를 추정합니다.
#
# 로지스틱 회귀: 종속변수가 범주형이므로 **최대우도법(Maximum Likelihood Estimation)**을 사용합니다.

# %% [markdown]
# # 47. 의사결정나무에 대한 설명으로 옳은 것을 모두 고르시오.
# 가. 의사결정나무는 동질성이 커지는 방향으로 분기한다. 나. 정규성 가정이 필요하다. 다. 교호작용은 변수들 간의 조합이 예측에 미치는 영향을 나타내는데 사용한다.
#
# ① 가, 나
#
# ② 나, 다
#
# ③ 가, 다
#
# ④ 가, 나, 다

# %% [markdown]
# 가. 동질성이 커지는 방향으로 분기, 나. 정규성 가정 필요, 다. 교호작용 파악 가능
#
# 정답: ③ 가, 다
#
# 설명:
#
# 가: 맞음. 순도(Purity)가 높고 불순도(Entropy)가 낮은 방향으로 나뉩니다.
#
# 나: 틀림. 의사결정나무는 비모수적 방법으로 데이터의 정규성 가정이 필요 없습니다.
#
# 다: 맞음. 여러 변수가 조합되어 분기되므로 변수 간 교호작용이 자동으로 반영됩니다.

# %% [markdown]
# # 48. 다음 보기를 참고하여 인공신경망의 출력값으로 알맞은 것은?
# 은닉노드가 2개, 출력노드가 1개이고 편향이 0.2 은닉노드 값은 각각 0.2, 0.1이고 가중치는 각각 0.4, 0.5
#
# ① 0.33
#
# ② 0.44
#
# ③ 0.55
#
# ④ 1

# %% [markdown]
# 정답: ① 0.33
#
# 설명:출력값 = $(가중치1 \times 노드1) + (가중치2 \times 노드2) + 편향$$= (0.4 \times 0.2) + (0.5 \times 0.1) + 0.2$$= 0.08 + 0.05 + 0.2 = 0.33$

# %% [markdown]
# # 49. 서포트벡터머신(SVM)에 대한 설명으로 옳지 않은 것은?
# ① 집단 사이의 마진이 최대화하는 기준인 초평면을 학습한다.
#
# ② 모델 훈련을 통한 최적화가 필요 없다.
#
# ③ 분류와 회귀에서 모두 사용할 수 있다.
#
# ④ 커널 함수를 이용하여 비선형 분류를 가능하게 한다.

# %% [markdown]
# 정답: ② 모델 훈련을 통한 최적화가 필요 없다.
#
# 설명: SVM은 마진을 최대화하는 초평면을 찾기 위해 복잡한 **최적화 문제(Quadratic Programming)**를 풀어야 하는 모델입니다.

# %% [markdown]
# # 50. 다음 보기의 식으로 알맞은 것은?$$d(x,y) = \left( \sum_{j=1}^{m} |x_j - y_j|^p \right)^{1/p}$$
# ① 마할라노비스거리
#
# ② 유클리드거리
#
# ③ 맨하탄거리
#
# ④ 민코우스키거리

# %% [markdown]
# 정답: ④ 민코우스키거리
#
# 설명:민코우스키 거리는 유클리드 거리와 맨해튼 거리를 일반화한 식으로, $p$값에 따라 거리를 정의합니다.

# %% [markdown]
# # 51. 다음 보기를 참고하여 위험도와 승산비로 알맞은 것은?구분불량양호합계신공정10490500구공정40460500합계509501000
# ① 위험도: 4, 승산비: $(0.02 \times 0.98) \div (0.08 \times 0.92)$
#
# ② 위험도: 4, 승산비: $(0.02 \times 0.92) \div (0.08 \times 0.98)$
#
# ③ 위험도: 0.25, 승산비: $(0.02 \times 0.98) \div (0.08 \times 0.92)$
#
# ④ 위험도: 0.25, 승산비: $(0.02 \times 0.92) \div (0.08 \times 0.98)$

# %% [markdown]
# 정답: ② 위험도: 4, 승산비: (0.02 * 0.92) / (0.08 * 0.98)
#
# 설명:신공정 불량률: $10/500 = 0.02$, 구공정 불량률: $40/500 = 0.08$상대 위험도: $0.08 / 0.02 = 4$ (구공정이 신공정보다 4배 위험)승산비는 각 집단의 (성공확률 / 실패확률)의 비율로 계산됩니다.

# %% [markdown]
# # 52. 주성분분석(PCA)에 대한 설명으로 옳은 것은?
# 가. 변수들은 정규분포 관계가 있다. 나. 차원축소는 변수들 간에 관계가 없어야 한다. 다. 분산의 최대화를 추구한다.
#
# ① 가
#
# ② 다
#
# ③ 가, 다
#
# ④ 가, 나, 다

# %% [markdown]
# 정답: ③ 가, 다
#
# 설명:
#
# 가: PCA는 변수들 간의 선형 결합을 이용하므로 정규분포 가정이 있으면 결과가 더 안정적입니다.
#
# 나: 틀림. PCA는 오히려 변수들 간의 상관관계가 높을 때 차원 축소 효율이 좋습니다.
#
# 다: 맞음. 원래 데이터의 **분산을 최대한 보존(최대화)**하는 축을 찾습니다.

# %% [markdown]
# # 53. 다음 주성분분석(PCA) 표를 주어진 후 전체분산에 대한 3번째 요인에 대한 설명률은?
#
# PC1PC2PC3PC4PC5PC6Standard Deviation1.5390.7590.4590.3440.2820.143Proportion variance0.7050.1710.0630.0350.0200.006Culmulative variance accounted for0.7050.8760.9380.9740.9941.000
#
# ① 6.3%
#
# ② 93.8%
#
# ③ 45.9%
#
# ④ 1%

# %% [markdown]
# 정답: ① 6.3%
#
# 설명: 표에서 'Proportion variance' 행의 PC3 열을 보면 0.063이라고 적혀 있습니다. 이를 백분율로 환산하면 6.3%입니다.

# %% [markdown]
# # 54. 다음 중 다변량분산분석(MANOVA)에 대한 설명으로 옳은 것은?
# ① 1개의 독립변수와 1개의 종속변수인 경우 사용한다.
#
# ② 다수의 독립변수와 다수의 종속변수인 경우 사용한다.
#
# ③ 다수의 독립변수와 1개의 종속변수인 경우 사용한다.
#
# ④ 독립변수는 연속형, 독립형 상관없이 사용한다.

# %% [markdown]
# 정답: ② 다수의 독립변수와 다수의 종속변수인 경우 사용한다.
#
# 설명: ANOVA는 종속변수가 1개일 때 사용하고, MANOVA는 **종속변수가 2개 이상(다변량)**일 때 그 차이를 검정하기 위해 사용합니다.

# %% [markdown]
# # 55. 차원축소의 목적으로 옳지 않은 것은?
# ① 특징 추출
#
# ② 설명력 증가
#
# ③ 노이즈 제거
#
# ④ 데이터 정제

# %% [markdown]
# 정답: ④ 데이터 정제
#
# 설명: 차원 축소는 특징 추출, 시각화, 노이즈 제거, 모델 복잡도 감소 등을 위해 수행합니다. 결측치나 이상치를 처리하는 '데이터 정제'는 차원 축소의 직접적인 목적이 아닙니다.

# %% [markdown]
# # 56. 다음 중 분류 모델로의 나이브 베이즈에 대한 설명으로 가장 옳은 것은?
# ① 모델이 복잡하고 계산속도가 느리다.
#
# ② 사전확률과 사후확률을 토대로 우도를 계산한다.
#
# ③ 독립변수들 간의 상관성을 가정한다.
#
# ④ 노이즈와 결측 데이터에 약하다.

# %% [markdown]
# 정답: ② 사전확률과 사후확률을 토대로 우도를 계산한다.
#
# 설명: 나이브 베이즈는 베이즈 정리를 기반으로 하며, 각 변수가 독립이라는 가정하에 계산 속도가 매우 빠르고 간단하다는 장점이 있습니다.

# %% [markdown]
# # 57. 다음 괄호에 들어갈 말로 옳은 것은?
# 시퀀스-투-시퀀스(Seq2seq)에서 인코더를 통해 ( )가 만들어지고, 디코더를 통해 출력 시퀀스가 된다.
#
# ① Eigen vector
#
# ② Context vector
#
# ③ Zero vector
#
# ④ Basis vector

# %% [markdown]
# 정답: ② Context vector
#
# 설명: Seq2seq 모델에서 인코더는 입력 문장의 정보를 압축하여 하나의 고정된 크기의 벡터로 만드는데, 이를 **컨텍스트 벡터(Context Vector)**라고 합니다.

# %% [markdown]
# # 58. 텍스트 마이닝에 대한 설명으로 옳지 않은 것은?
# ① 사용하지 않거나 분석에 필요 없는 불용어(Stopword)를 제거한다.
#
# ② 어간을 추출하는 어간추출(Stemming) 작업을 한다.
#
# ③ 주어진 코퍼스(Corpus)에서 토큰(Token) 단위로 나누는 토큰화(Tokenization) 한다.
#
# ④ 문장마다 포스 태깅(Pos Tagging) 해서 의미를 찾아낸다.

# %% [markdown]
# 정답: ④ 문장마다 포스 태깅(Pos Tagging) 해서 의미를 찾아낸다.
#
# 설명: 포스 태깅(품사 부착)은 단어의 품사를 식별하는 단계이지, 그 자체로 문장의 전체 '의미'를 완전히 찾아내는 최종 작업은 아닙니다. (의미 분석은 보통 그 이후 단계에서 이루어집니다.)

# %% [markdown]
# # 59. 다음 중 부스팅에 대한 설명으로 옳지 않은 것은?
# ① AdaBoost는 약한 모델(Weak Learner)의 오류 데이터에 가중치를 부여한다.
#
# ② GBM은 예측 성능이 높은 욕심쟁이 알고리즘(Greedy Algorithm)을 사용한다.
#
# ③ XGBoost는 GBM을 개선한 방식이지만 GBM보다 속도가 늦다.
#
# ④ LightGBM은 기존 트리 방식과 다르게 leaf 중심으로 분기한다.

# %% [markdown]
# 정답: ③ XGBoost는 GBM을 개선한 방식이지만 GBM보다 속도가 늦다.
#
# 설명: XGBoost는 GBM의 느린 속도를 개선하기 위해 병렬 처리와 다양한 최적화 기법을 도입한 알고리즘이므로, GBM보다 훨씬 빠릅니다.

# %% [markdown]
# # 60. 앙상블 기법에 대한 설명으로 옳지 않은 것은?
# ① 서로 다른 모델을 결합함으로써 개별 모델의 과적합을 줄일 수 있다.
#
# ② 이상값이나 잘못된 데이터에 대한 영향을 줄일 수 있다.
#
# ③ 단순 모델보다 항상 성능이 좋다.
#
# ④ 과적합 문제가 발생할 수 있다.

# %% [markdown]
# 정답: ③ 단순 모델보다 항상 성능이 좋다.
#
# 설명: 앙상블이 일반적으로 성능이 좋긴 하지만, 데이터가 너무 적거나 개별 모델들이 모두 편향되어 있다면 항상 단순 모델보다 좋다고 보장할 수는 없습니다.

# %% [markdown]
# # 61. 다음 중 비모수검정에 대한 설명으로 가장 옳지 않은 것은?
# ① 비모수통계는 모수통계보다 검정력이 높다.
#
# ② 범주형 자료와 같은 서열척도 데이터에 적용할 수 있다.
#
# ③ 등간, 비율척도를 서열화하여 서열척도로 분석할 수 있다.
#
# ④ 순위(Rank)나 부호(Sign)에 기초한 방법이기 때문에, 이상값의 영향을 덜 받는다.

# %% [markdown]
# 정답: ① 비모수통계는 모수통계보다 검정력이 높다.
#
# 설명: 정규성 가정을 만족하는 데이터라면 모수통계가 비모수통계보다 검정력(Power)이 더 높습니다. 비모수통계는 가정이 적은 대신 정보를 요약(순위화)하기 때문에 정보 손실이 발생합니다.

# %% [markdown]
# # 62. 다음 중 혼동행렬에 대한 평가지표로 옳은 것은?(예측값)Positive(1)Negative(0)Positive(1)( 가 )( 다 )Negative(0)( 나 )-
# ① 가 - 정확한 판단, 나 - 2종오류, 다 - 1종오류
#
# ② 가 - 정확한 판단, 나 - 1종오류, 다 - 2종오류
#
# ③ 가 - 1종오류, 나 - 2종오류, 다 - 정확한 판단
#
# ④ 가 - 2종오류, 나 - 1종오류, 다 - 정확한 판단

# %% [markdown]
# 정답: ② 가 - 정확한 판단, 나 - 1종오류, 다 - 2종오류
#
# 설명:
#
# 가: 실제 P를 P로 예측 (정확)
#
# 나: 실제 N인데 P로 예측 (1종 오류, False Positive)
#
# 다: 실제 P인데 N으로 예측 (2종 오류, False Negative)

# %% [markdown]
# 63. 다음 혼동행렬을 계산한 값으로 옳지 않은 것은?예측값실제값(참)실제값(거짓)합참48250거짓123850합6040100① 정확도 = 0.86② 재현율 = 0.8③ 특이도 = 0.95④ 정밀도 = 0.9

# %% [markdown]
# 정답: ④ 정밀도 = 0.9
#
# 설명:
#
# 정확도: $(48+38)/100 = 0.86$
#
# 재현율: $48/60 = 0.8$
#
# 특이도: $38/40 = 0.95$
#
# 정밀도: $48/(48+2) = 48/50 = 0.96$. (④번의 0.9는 틀림)

# %% [markdown]
# # 64. 실제 Positive인 경우에 Positive로 예측한 것은?
# ① 정확도
#
# ② 정밀도
#
# ③ 재현율
#
# ④ 특이도

# %% [markdown]
# 정답: ③ 재현율(Recall)
#
# 설명: 실제 양성인 것들 중에서 모델이 양성이라고 맞춘 비율을 재현율 또는 민감도(Sensitivity)라고 합니다.

# %% [markdown]
# # 65. 다음 수식 중에 옳지 않은 것은?
#
# ① $MPE = \frac{100\%}{n} \sum_{i=1}^{n} (\frac{y_i - \hat{y}_i}{y_i})$
#
# ② $MSE = \frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2$
#
# ③ $MAE = \frac{1}{n} \sum_{i=1}^{n} |y_i - \hat{y}_i|$
#
# ④ $MAPE = \frac{1}{n} \sum_{i=1}^{n} |\frac{y_i - \hat{y}_i}{y_i}|$

# %% [markdown]
# 정답: ① $MPE$ 수식
#
# 설명:보통 MPE는 오차($y - \hat{y}$)를 실제값($y$)으로 나눈 값의 평균입니다.
#
# ①번 수식의 형태는 표준적인 지표 정의와 차이가 있거나 오타가 포함되어 있을 가능성이 큽니다. (MAPE는 절대값을 취합니다.)

# %% [markdown]
# # 66. 다음 중 ROC곡선에 대한 설명으로 옳지 않은 것은?
# ① FPR 값에 따른 TPR 값 그래프이다.
#
# ② FPR이 작아도 TPR이 클 수 있다.
#
# ③ 무작위의 경우 TPR과 FPR은 같은 곳으로 수렴한다.
#
# ④ AUC가 작을수록 모델 성능이 좋다.

# %% [markdown]
# 정답: ④ AUC가 작을수록 모델 성능이 좋다.
#
# 설명: ROC 곡선 아래의 면적인 AUC는 1에 가까울수록(클수록) 모델의 분류 성능이 우수함을 의미합니다.

# %% [markdown]
# # 67. 교차검증에 대한 설명으로 가장 옳은 것은?
# ① 학습 데이터에서 얻은 오류추정치가 검증 데이터보다 많이 작다면 과적합되어 있을 수 있다.
#
# ② 시계열 데이터를 사용하기 용이하다.
#
# ③ 교차검증으로는 과적합을 해결할 수 없다.
#
# ④ 일반적으로 모델의 생성 시간이 매우 감소된다.

# %% [markdown]
# 정답: ① 학습 데이터에서 얻은 오류추정치가 검증 데이터보다 많이 작다면 과적합되어 있을 수 있다.
#
# 설명: 학습 데이터 점수는 높은데 검증 데이터 점수가 낮다면, 모델이 학습 데이터에만 너무 맞춰진 과적합(Overfitting) 상태임을 시사합니다.

# %% [markdown]
# # 68. 다음 중 K-fold 교차검증에 대한 설명으로 옳지 않은 것은?
# ① k-1개 데이터셋은 학습용, 1개 데이터셋은 검증용으로 사용한다. ② 데이터셋은 행으로만 나눈다. ③ 데이터셋은 k번 반복한다. ④ 데이터셋은 각각 한 번씩만 검정용으로 사용한다.

# %% [markdown]
# 정답: ② 데이터셋은 행으로만 나눈다.
#
# 설명: K-fold는 데이터를 K개의 그룹(Fold)으로 나누어 순환하며 검증하는 방식입니다. ②번 '행으로만 나눈다'는 표현은 교차검증의 핵심 원리와는 다소 거리가 있는 지엽적인 설명입니다.

# %% [markdown]
# # 69. 지도학습 모델의 적합도 검정에 대한 설명으로 옳지 않은 것은?
# ① 자기상관성
#
# ② 카이제곱검정
#
# ③ 샤피로-윌크검정
#
# ④ 콜모고로프-스미르노프검정

# %% [markdown]
# 정답: ① 자기상관성
#
# 설명: 자기상관성은 주로 시계열 데이터의 잔차 분석에서 확인하는 요소이지, 일반적인 지도학습 모델의 적합도 검정 지표(카이제곱, 샤피로-윌크 등 분포 검정)와는 성격이 조금 다릅니다.

# %% [markdown]
# 70. 다음은 회귀분석 후 모델 적합도 검정을 위한 분산분석표이다. 빈 값에 대한 설명으로 옳지 않은 것은?
#
# 구분제곱합자유도평균제곱F값회귀(R)3502(ㄴ)(ㄷ)오차(E)(ㄱ)531.5총(T)(ㄹ)7
#
# ① (ㄱ) - 157.5
#
# ② (ㄴ) - 175
#
# ③ (ㄷ) - 7.5
#
# ④ (ㄹ) - 507.5

# %% [markdown]
# 정답: ③ (ㄷ) - 7.5
#
# 설명:
#
# 총 제곱합(ㄹ) = 회귀 제곱합(350) + 오차 제곱합(ㄱ).
#
# 평균제곱(ㄴ) = 제곱합 / 자유도 = $350 / 2 = 175$.
#
# F값(ㄷ) = 회귀 평균제곱 / 오차 평균제곱 = $175 / 31.5 \approx 5.55$. (③번의 7.5는 틀림)

# %% [markdown]
# # 71. 다음 중 과적합 방지 방안으로 옳지 않은 것은?
# ① 규제화를 사용한다.
#
# ② 매개변수를 늘린다.
#
# ③ 조기 종료한다.
#
# ④ 드롭아웃을 사용한다.

# %% [markdown]
# 정답: ② 매개변수를 늘린다.
#
# 설명: 매개변수(Parameter)를 늘리는 것은 모델을 더 복잡하게 만드는 것이므로 과적합을 오히려 심화시킵니다. 과적합을 방지하려면 모델을 단순화해야 합니다.

# %% [markdown]
# # 72. 파라미터와 하이퍼파라미터에 대한 설명으로 옳지 않은 것은?
# ① 파라미터는 학습을 통해 최적화 가능하다.
#
# ② 파라미터는 경사하강법으로 추정할 수 있다.
#
# ③ 하이퍼파라미터는 학습 중에 변하지 않는다.
#
# ④ 은닉층 수와 학습률은 하이퍼파라미터의 사례이다.

# %% [markdown]
# 정답: ③ 하이퍼파라미터는 학습 중에 변하지 않는다.
#
# 설명: 하이퍼파라미터(학습률 등)는 사용자가 학습 전에 설정하며, 학습 과정에서 데이터에 의해 자동으로 최적화되지 않는 값입니다. '변하지 않는다'는 말은 맞지만, 문맥상 다른 보기가 더 명확한 답일 수 있습니다. (문제 복원상 ③번이 답으로 꼽히는 경우가 많습니다.)

# %% [markdown]
# # 73. 경사하강법의 설명으로 옳은 것은?
# ① 확률적 경사하강법은 전미분을 사용한다.
#
# ② 모멘텀은 관성을 이용하여 지역최소점이 아닌 글로벌 최소점으로 구한다.
#
# ③ 아다그라드(Adaptive gradient)는 이전 기울기 값과 관계없다.
#
# ④ 아담(ADAM)은 학습률은 고려하지 않는다.

# %% [markdown]
# 정답: ② 모멘텀은 관성을 이용하여 지역최소점이 아닌 글로벌 최소점으로 구한다.
#
# 설명: 모멘텀(Momentum)은 기울기에 가속도를 붙여 지역 최솟값(Local Minima)을 탈출하고 더 좋은 최솟값을 찾도록 돕는 기법입니다.

# %% [markdown]
# # 74. 다음 중 앙상블 기법에 대한 설명 중 적절하지 않은 것은?
# ① 보팅 - 예측한 결과값을 다수의 분류기 투표로 결정
#
# ② 랜덤포레스트 - 배깅과 부스팅보다 더 많은 무작위성을 주어 여러 개의 약한 학습기들을 생성하고 결합
#
# ③ 배깅 - 부트스트랩으로 데이터의 다양성을 확보하여 다양한 결과를 분류 및 예측
#
# ④ 스태킹 - 동일한 표본으로 다양한 유형의 모델을 학습

# %% [markdown]
# 정답: ② 랜덤포레스트 설명
#
# 설명: 랜덤포레스트는 **배깅(Bagging)**의 대표적인 사례입니다. '부스팅보다 더 많은 무작위성을 주어...'라는 설명은 랜덤포레스트의 정의로 적절하지 않습니다.

# %% [markdown]
# # 75. 다음 중 데이터시각화 절차로 알맞은 것은?
# ① 데이터 획득 - 구조화 - 모델 훈련 - 모델 성능평가 - 시각화 모델 선택 - 시각화 표현 및 재정의
#
# ② 데이터 획득 - 모델 훈련 - 모델 성능평가 - 구조화 - 시각화 모델 선택 - 시각화 표현 및 재정의
#
# ③ 데이터 획득 - 시각화 표현 및 재정의 - 시각화 모델 선택 - 구조화 - 모델 훈련 - 모델 성능평가
#
# ④ 데이터 획득 - 구조화 - 시각화 모델 선택 - 시각화 표현 및 재정의 - 모델 훈련 - 모델 성능평가

# %% [markdown]
# 정답: ④ 데이터 획득 - 구조화 - 시각화 모델 선택 - 시각화 표현 및 재정의 - 모델 훈련 - 모델 성능평가
#
# 설명: 데이터를 먼저 가져오고 분석 목적에 맞게 구조를 잡은 뒤, 적절한 시각화 방법을 선택하여 표현하는 흐름이 가장 자연스럽습니다.

# %% [markdown]
# # 76. 국회의원 선거에서 지역 면적이 아니라 지역구에 당선된 국회의원 수에 따라 시각화하고자 할 때 적합한 시각화 도구로 옳은 것은?
# ① 단계구분도
#
# ② 등치선도
#
# ③ 격자 카토그램
#
# ④ 픽토그램

# %% [markdown]
# 정답: ③ 격자 카토그램(Cartogram)
#
# 설명: 실제 지형의 면적이 아니라 특정 통계값(인구, 국회의원 수 등)의 크기에 따라 지도 면적을 의도적으로 왜곡하여 그리는 방식을 카토그램이라고 합니다.

# %% [markdown]
# # 77. 다음 중 지역 별 매출액과 수익율에 대해 나타내는 시각화 기법으로 가장 알맞은 것은?
# ① 매출 - 카토그램, 수익 - 버블차트
#
# ② 매출 - 픽토그램, 수익 - 버블차트
#
# ③ 매출 - 카토그램, 수익 - 산점도
#
# ④ 매출 - 픽토그램, 수익 - 산점도

# %% [markdown]
# 정답: ③ 매출 - 카토그램, 수익 - 산점도
#
# 설명: 매출액과 같은 양적인 정보는 지도형(카토그램)으로, 수익률과 매출의 관계 등은 산점도로 표현하는 것이 일반적입니다.

# %% [markdown]
# # 78. 산점도에서 설명하는 연도별 출생인구 수에 대한 설명으로 옳은 것은?
#
# (이미지 내 산점도 그래프 참조)
#
# ① 2014년이 2015년보다 출생인구가 높다.
#
# ② 2000년 출생인구 수가 60만명 이상이다.
#
# ③ 2005년 출생인구 수가 2011년 출생인구 수보다 높다.
#
# ④ 연도별로 항상 감소하고 있다.

# %% [markdown]
# 정답: ② 2000년 출생인구 수가 60만 명 이상이다.
#
# 설명: 그래프상의 데이터를 확인했을 때 2000년 지점의 Y축 값이 60만 위쪽에 위치한다면 ②번이 옳은 설명이 됩니다.

# %% [markdown]
# # 79. 다음 중 인포그래픽에 대한 사례로 잘 연결된 것 고르시오.
# (가) 지역별 코로나 발생률 (나) 월별 코로나 발생률
#
# ① 가 - 지도형, 나 - 타임라인형
#
# ② 가 - 지도형, 나 - 도표형
#
# ③ 가 - 스토리텔링형, 나 - 타임라인형
#
# ④ 가 - 스토리텔링형, 나 - 도표형

# %% [markdown]
# 정답: ① 가 - 지도형, 나 - 타임라인형
#
# 설명:
#
# 지역별 발생률 → 지도 위에 표시하므로 지도형.
#
# 월별(시간 흐름) 발생률 → 시간 순서대로 나열하므로 타임라인형.

# %% [markdown]
# # 80. 분석 활용 계획에 대한 설명으로 옳지 않은 것은?
# ① 이해관계자와 협의하여 계획을 수립한다.
#
# ② 결과물이나 모델의 성능을 지속적으로 평가하고 개선하기 위한 방안을 포함해야 한다.
#
# ③ 목적에 따라 적용방안을 변경한다.
#
# ④ 데이터 적용은 모델링과 분석이 모두 끝난 후 적용계획을 세우기 시작한다.

# %% [markdown]
# 정답: ④ 데이터 적용은 모델링과 분석이 모두 끝난 후 적용계획을 세우기 시작한다.
#
# 설명: 분석 활용 계획이나 적용 방안은 분석 기획 초기 단계부터 이해관계자와 협의하여 함께 고려해야 합니다. 모든 작업이 끝난 뒤에 계획을 세우면 현장 적용에 어려움을 겪을 가능성이 큽니다.
